# %% [markdown]
# #### Logistic regression with a NN mindset
#
# Note: avoid for loops, use vectorized operations instead.
#
# Goal: build a general architecture of a learning algorithm, including
# - initialization of parameters
# - calculation of cost function and its gradient
# - using an optimization algorithm (gradient descent)
#
# combine all of these into a single function (`model`).

# %%
import numpy as np 
import matplotlib.pyplot as plt
import h5py
import scipy           
from PIL import Image
from scipy import ndimage                                                            
from lr_utils import load_dataset

# %% [markdown]
# problem details:
# cat(y=1) vs non-cat(y=0) binary classification
# - input: image of shape (num_px, num_px, 3)
# - output: probability of cat (y=1) or not cat (y=0)
#
# objective: to build a simple image recognition algorithm

# %%
# loading dataset
train_set_x_orig, train_set_y, test_set_x_orig, test_set_y, classes = load_dataset()

# %%
# see an example picture
index = 101
plt.imshow(train_set_x_orig[index])
plt.show()
print("y = " + str(train_set_y[:, index]) + ", it's a '" + classes[np.squeeze(train_set_y[:, index])].decode("utf-8") +  "' picture.")
# Out:
# y = [0], it's a 'non-cat' picture.

# %%
# few stats of dataset
m_train = train_set_x_orig.shape[0]
m_test = test_set_x_orig.shape[0]
num_px = train_set_x_orig.shape[1] # height = width = num_px
print(m_train, m_test, num_px)
# Out:
# 209 50 64

# %%
print(f"train_set_x shape: {train_set_x_orig.shape}")
print(f"train_set_y shape: {train_set_y.shape}")
print(f"test_set_x shape: {test_set_x_orig.shape}")
print(f"test_set_y shape: {test_set_y.shape}")
# Out:
# train_set_x shape: (209, 64, 64, 3)
# train_set_y shape: (1, 209)
# test_set_x shape: (50, 64, 64, 3)
# test_set_y shape: (1, 50)
